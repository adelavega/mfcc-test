# %% [markdown]
# Lets start with importing the new `Class`/`function`:

# %%
from pliers.extractors import MFCCEnergyExtractor

# %%
punk = 'Punk1.wav'

# %% [markdown]
# We set up two extractors, one for `timbre` and one for `pitch`:

# %%
timbre_extractor = MFCCEnergyExtractor(direction='low')
pitch_extractor = MFCCEnergyExtractor(direction='high')

# %% [markdown]
# We'll have a look at the respective outputs:

# %%
timbre_punk = timbre_extractor.transform(punk)
pitch_punk = pitch_extractor.transform(punk)

# %%
timbre_punk.data
# Out:
#      order  duration     onset  object_id  mfcc_energy_0  mfcc_energy_1  \
# 0        0   0.01161  0.000000          0       2.692913       3.186388
# 1        1   0.01161  0.011610          0       2.583367       3.849492
# 2        2   0.01161  0.023220          0       3.041528       4.804643
# 3        3   0.01161  0.034830          0       5.123451       8.778053
# 4        4   0.01161  0.046440          0       9.168691      18.127066
# ..     ...       ...       ...        ...            ...            ...
# 512    512   0.01161  5.944308          0       1.209840       1.268769
# 513    513   0.01161  5.955918          0       1.601161       1.861657
# 514    514   0.01161  5.967528          0       7.134812      13.195156
# 515    515   0.01161  5.979138          0       9.393862      17.208829
# 516    516   0.01161  5.990748          0       8.709353      14.884398
#
#      mfcc_energy_2  mfcc_energy_3  mfcc_energy_4  mfcc_energy_5  ...  \
# 0         1.714615       0.824631       0.474225       0.389017  ...
# 1         3.810020       3.483053       2.786572       1.949519  ...
# 2         4.658725       4.198931       3.393620       2.476228  ...
# 3         5.959926       3.415687       1.858388       1.093453  ...
# 4         9.554505       4.023309       1.697539       0.872347  ...
# ..             ...            ...            ...            ...  ...
# 512       1.161680       1.019366       0.870548       0.730888  ...
# 513       1.631451       1.319156       1.008209       0.762379  ...
# 514       7.585362       3.457743       1.490957       0.733494  ...
# 515       7.316792       2.438740       0.900661       0.480062  ...
# 516       5.757052       1.733281       0.606752       0.333152  ...
#
#      mfcc_energy_38  mfcc_energy_39  mfcc_energy_40  mfcc_energy_41  \
# 0          0.011587        0.013811        0.014250        0.012185
# 1          0.008164        0.009261        0.009415        0.007665
# 2          0.010742        0.012170        0.011928        0.008721
# 3          0.016751        0.019280        0.018390        0.012221
# 4          0.020176        0.022500        0.019784        0.011951
# ..              ...             ...             ...             ...
# 512        0.006562        0.007645        0.007595        0.006187
# 513        0.010966        0.012372        0.011885        0.008872
# 514        0.016712        0.018174        0.016566        0.011248
# 515        0.017467        0.018282        0.015434        0.009634
# 516        0.016253        0.016741        0.013400        0.008021
#
#      mfcc_energy_42  mfcc_energy_43  mfcc_energy_44  mfcc_energy_45  \
# 0          0.009227        0.007334        0.007630        0.012565
# 1          0.005028        0.003162        0.002593        0.003855
# 2          0.004749        0.002372        0.001587        0.002137
# 3          0.005636        0.002288        0.001264        0.001521
# 4          0.005155        0.002066        0.001183        0.001504
# ..              ...             ...             ...             ...
# 512        0.004422        0.003329        0.003391        0.005893
# 513        0.005290        0.003054        0.002359        0.003421
# 514        0.005750        0.002723        0.001738        0.002249
# 515        0.004699        0.002267        0.001561        0.002214
# 516        0.003971        0.002087        0.001629        0.002572
#
#      mfcc_energy_46  mfcc_energy_47
# 0          0.035658        0.163939
# 1          0.012710        0.089478
# 2          0.007478        0.065364
# 3          0.005363        0.053318
# 4          0.005508        0.054808
# ..              ...             ...
# 512        0.019616        0.117614
# 513        0.011424        0.084067
# 514        0.007645        0.065790
# 515        0.007979        0.068699
# 516        0.009585        0.077721
#
# [517 rows x 52 columns]

# %%
pitch_punk.data
# Out:
#      order  duration     onset  object_id  mfcc_energy_0  mfcc_energy_1  \
# 0        0   0.01161  0.000000          0       0.407717       0.395342
# 1        1   0.01161  0.011610          0       0.228950       0.379845
# 2        2   0.01161  0.023220          0       0.215985       0.312935
# 3        3   0.01161  0.034830          0       0.611081       1.302701
# 4        4   0.01161  0.046440          0       0.722589       2.240846
# ..     ...       ...       ...        ...            ...            ...
# 512    512   0.01161  5.944308          0       0.307375       0.449594
# 513    513   0.01161  5.955918          0       0.190727       0.413467
# 514    514   0.01161  5.967528          0       0.373089       0.764414
# 515    515   0.01161  5.979138          0       0.907619       2.076243
# 516    516   0.01161  5.990748          0       1.593976       1.912223
#
#      mfcc_energy_2  mfcc_energy_3  mfcc_energy_4  mfcc_energy_5  ...  \
# 0         0.879351       2.760476       2.992807       0.647293  ...
# 1         1.105769       1.424789       2.256650       0.909053  ...
# 2         1.062279       1.718391       2.483122       1.037771  ...
# 3         1.672485       0.899686       1.668038       0.751944  ...
# 4         3.592158       0.856462       0.927925       1.102901  ...
# ..             ...            ...            ...            ...  ...
# 512       1.052222       1.017272       1.039902       0.729455  ...
# 513       1.179917       0.661388       0.899931       0.776892  ...
# 514       1.571254       0.702019       0.640784       0.467959  ...
# 515       2.505828       0.806876       0.807471       0.777841  ...
# 516       1.332951       0.690430       0.536102       0.645276  ...
#
#      mfcc_energy_38  mfcc_energy_39  mfcc_energy_40  mfcc_energy_41  \
# 0          1.321803        1.276252        1.348036        1.077123
# 1          0.878553        1.101031        1.284537        0.925143
# 2          0.871740        1.010213        0.936354        0.724166
# 3          0.963837        0.841905        0.811172        0.610597
# 4          0.848181        0.956675        1.056464        0.655495
# ..              ...             ...             ...             ...
# 512        0.800814        0.906249        1.055411        0.795456
# 513        0.762975        1.099868        1.061291        0.755423
# 514        0.677612        0.951316        1.084137        0.735977
# 515        0.702169        0.865963        1.151027        0.654495
# 516        0.758220        0.837628        1.016159        0.625637
#
#      mfcc_energy_42  mfcc_energy_43  mfcc_energy_44  mfcc_energy_45  \
# 0          0.911428        0.731822        0.308126        0.380047
# 1          1.035304        0.728107        0.206770        0.244605
# 2          1.007190        0.660665        0.144247        0.148993
# 3          0.748961        0.630463        0.140684        0.123332
# 4          0.710356        0.593488        0.134209        0.121648
# ..              ...             ...             ...             ...
# 512        0.781490        0.475511        0.153799        0.310149
# 513        0.916110        0.496764        0.122709        0.228995
# 514        0.766854        0.377048        0.092899        0.187299
# 515        0.571391        0.357956        0.093870        0.191615
# 516        0.680912        0.398538        0.097239        0.220192
#
#      mfcc_energy_46  mfcc_energy_47
# 0          0.934372        0.870519
# 1          0.746350        0.885190
# 2          0.558539        0.899110
# 3          0.511256        0.888396
# 4          0.508259        0.882017
# ..              ...             ...
# 512        1.034997        0.790966
# 513        0.869119        0.801060
# 514        0.800703        0.818596
# 515        0.890395        0.809246
# 516        0.970272        0.784484
#
# [517 rows x 52 columns]

# %% [markdown]
# KK, visualizing things might also be helpful.

# %%
from librosa import display
display.specshow(timbre_punk.data.iloc[:, 4:].T.to_numpy(), y_axis='mel', x_axis='time')

# %%
display.specshow(pitch_punk.data.iloc[:, 4:].T.to_numpy(), y_axis='mel', x_axis='time')

# %% [markdown]
# Now we'll compare that to the output of the function Peer used so far:

# %%
# define dct-function like Hanke et al. for timbre, pitch and spectrum
def dct_II(N):
    # Create N x N matrix of discrete cosine transform coefficients
    # Uses DCT-II formula:https://en.wikipedia.org/wiki/Discrete_cosine_transform#DCT-II
    d = np.array([np.cos(np.pi / N * (np.arange(N) + 0.5) * k)
                  for k in np.arange(N)],
                 dtype='f4')
    d[0] *= 1 / np.sqrt(2)
    d *= np.sqrt(2.0 / N)
    return d

# %%
from librosa import load, feature
import numpy as np
y, sr = load(punk, sr=None)
nBands = 48
nCoefs = 13
mfcc = feature.mfcc(y=y, sr=sr, n_mels=48)

# %%
# timbre 
DCT = dct_II(nBands)
lq_mfs = np.dot(DCT[:nCoefs].T, mfcc[:nCoefs])
lq_mfs_norm = 10 ** (lq_mfs / 20.)

# %%
lq_mfs
# Out:
# array([[ 11.709036 ,  12.977407 ,  13.24665  , ...,  18.592453 ,
#          20.678272 ,  18.668432 ],
#        [  9.741731 ,  12.58688  ,  12.960153 , ...,  16.71416  ,
#          17.790594 ,  15.590283 ],
#        [  6.5710077,  11.72063  ,  12.281917 , ...,  13.348003 ,
#          12.890542 ,  10.439315 ],
#        ...,
#        [-38.643826 , -41.78181  , -42.94592  , ..., -42.8414   ,
#         -42.926643 , -38.778397 ],
#        [-44.0027   , -49.653927 , -52.84021  , ..., -53.11964  ,
#         -53.09533  , -46.23628  ],
#        [-47.09593  , -54.296352 , -58.698204 , ..., -59.232292 ,
#         -59.11314  , -50.604492 ]], dtype=float32)

# %%
lq_mfs.shape
# Out:
# (48, 517)

# %%
# visualize timbre
display.specshow(lq_mfs, y_axis='mel', x_axis='time')

# %%
display.specshow(lq_mfs_norm, y_axis='mel', x_axis='time')

# %%
lq_mfs_norm_pliers = timbre_punk.data.iloc[:, 4:].T.to_numpy()

# %%
display.specshow(lq_mfs_norm_pliers, y_axis='mel', x_axis='time')

# %%
# pitch
mfs = feature.melspectrogram(y=y, sr=sr, n_mels=48)
DCT = dct_II(nBands)
mfcc = np.dot(DCT, 20 * np.log10(mfs + np.finfo(float).eps))
hq_mfs = np.dot(DCT[nCoefs:].T, mfcc[nCoefs:])
hq_mfs_norm = 10 ** (hq_mfs / 20.)

# %%
# pitch
DCT = dct_II(nBands)
mfcc_l = feature.mfcc(y=y, sr=sr, n_mfcc=48)
hq_mfs_librosa = np.dot(DCT[nCoefs:].T, mfcc_l[nCoefs:])
hq_mfs_norm_librosa = 10 ** (hq_mfs_librosa / 20.)

# %%
hq_mfs.shape
# Out:
# (48, 517)

# %%
# visualize pitch
display.specshow(hq_mfs, y_axis='mel', x_axis='time')

# %%
display.specshow(hq_mfs_norm, y_axis='mel', x_axis='time')

# %%
display.specshow(hq_mfs_norm_librosa, y_axis='mel', x_axis='time')

# %%
hq_mfs_norm_pliers = pitch_punk.data.iloc[:, 4:].T.to_numpy()

# %%
display.specshow(hq_mfs_norm_pliers, y_axis='mel', x_axis='time')

# %% [markdown]
# # Compare DCTs

# %%
DCT = dct_II(nBands)

# %%
from scipy.fft import dct

# %%
mfs = feature.melspectrogram(y=y, sr=sr, n_mels=48)
mfcc_michael = np.dot(DCT, 20 * np.log10(mfs + np.finfo(float).eps))
mfcc_scipy = dct(mfs, n=nBands)

# %%
display.specshow(mfcc_scipy, y_axis='mel', x_axis='time')

# %%
display.specshow(mfcc_michael, y_axis='mel', x_axis='time')

# %%
yIn [12]:

# timbre 
DCT = dct_II(nBands)
# Out:
# array([-0.02426147, -0.0402832 , -0.01956177, ..., -0.09111023,
#        -0.10568237, -0.07714844], dtype=float32)
